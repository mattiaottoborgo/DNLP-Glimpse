# %%
import argparse
import datetime
from pathlib import Path

import pandas as pd
from datasets import Dataset
from tqdm import tqdm

import nltk
import os

# %%
def prepare_dataset(dataset_path) -> Dataset:
    
    try:
        dataset = pd.read_csv(dataset_path)
    except:
        raise ValueError(f"Unknown dataset {dataset_path}")

    # make a dataset from the dataframe
    dataset = Dataset.from_pandas(dataset)

    return dataset

# %%
def evaluate_summarizer(dataset: Dataset) -> Dataset:
    """
    @param dataset: A dataset with the text
    @return: The same dataset with the summaries added
    """
    # create a dataset with the text and the summary

    # create a dataloader

    # generate summaries
    summaries = []
    print("Generating summaries...")

    # (tqdm library for progress bar) 
    for sample in tqdm(dataset):
        text = sample["text"] 
        
        text = text.replace('-----', '\n')
        sentences = nltk.sent_tokenize(text)
        # remove empty sentences
        sentences = [sentence for sentence in sentences if sentence != ""]

        summaries.append(sentences)

    # add summaries to the huggingface dataset
    dataset = dataset.map(lambda example: {"summary": summaries.pop(0)})

    return dataset

# %% [markdown]
# ### 1. Extract candidates

# %%
# load the dataset
limit = 10
print("Loading dataset...")
dataset_path = "../../data/processed/all_reviews_2017.csv"
dataset = prepare_dataset(dataset_path)

# limit the number of samples
if limit is not None:
    _lim = min(limit, len(dataset))
    dataset = dataset.select(range(_lim))

# generate summaries
dataset = evaluate_summarizer(
    dataset,
)

df_dataset = dataset.to_pandas()
df_dataset = df_dataset.explode("summary")
df_dataset = df_dataset.reset_index()
# add an idx with  the id of the summary for each example
df_dataset["id_candidate"] = df_dataset.groupby(["index"]).cumcount()

# save the dataset
# add unique date in name
now = datetime.datetime.now()
date = now.strftime("%Y-%m-%d-%H-%M-%S")
output_dir = "data/candidates/"
output_path = (
    Path(output_dir)
    / f"extractive_sentences-_-none-_-{date}.csv" #f"extractive_sentences-{date}.csv"
    
)
output_path = f"../../data/candidates/extractive_sentences-_-none-_-{date}.csv"

# create output dir if it doesn't exist
#if not output_path.parent.exists():
#    output_path.parent.mkdir(parents=True, exist_ok=True)

df_dataset.to_csv(output_path, index=False, encoding="utf-8")

# in case of scripted run, print the output path
print(f"output_path: {output_path}")
# Out:
# Loading dataset...
# Generating summaries...
# 100%|██████████| 6/6 [00:00<00:00, 1930.49it/s]
# Map: 100%|██████████| 6/6 [00:00<00:00, 1704.54 examples/s]
# output_path: ../../data/candidates/extractive_sentences-_-none-_-2024-12-19-16-57-12.csv

# %%
df_dataset
# Out:
#      index                                         id  \
# 0        0  https://openreview.net/forum?id=r1rhWnZkg
# 1        0  https://openreview.net/forum?id=r1rhWnZkg
# 2        0  https://openreview.net/forum?id=r1rhWnZkg
# 3        0  https://openreview.net/forum?id=r1rhWnZkg
# 4        0  https://openreview.net/forum?id=r1rhWnZkg
# ..     ...                                        ...
# 112      5  https://openreview.net/forum?id=S1J0E-71l
# 113      5  https://openreview.net/forum?id=S1J0E-71l
# 114      5  https://openreview.net/forum?id=S1J0E-71l
# 115      5  https://openreview.net/forum?id=S1J0E-71l
# 116      5  https://openreview.net/forum?id=S1J0E-71l
#
#                                                   text  \
# 0    Summary: The paper presents low-rank bilinear ...
# 1    Summary: The paper presents low-rank bilinear ...
# 2    Summary: The paper presents low-rank bilinear ...
# 3    Summary: The paper presents low-rank bilinear ...
# 4    Summary: The paper presents low-rank bilinear ...
# ..                                                 ...
# 112  This paper proposes to leverage "surprisal" as...
# 113  This paper proposes to leverage "surprisal" as...
# 114  This paper proposes to leverage "surprisal" as...
# 115  This paper proposes to leverage "surprisal" as...
# 116  This paper proposes to leverage "surprisal" as...
#
#                                                   gold  \
# 0    The program committee appreciates the authors'...
# 1    The program committee appreciates the authors'...
# 2    The program committee appreciates the authors'...
# 3    The program committee appreciates the authors'...
# 4    The program committee appreciates the authors'...
# ..                                                 ...
# 112  Based on the feedback, I'm going to be rejecti...
# 113  Based on the feedback, I'm going to be rejecti...
# 114  Based on the feedback, I'm going to be rejecti...
# 115  Based on the feedback, I'm going to be rejecti...
# 116  Based on the feedback, I'm going to be rejecti...
#
#                                                summary  id_candidate
# 0    Summary: The paper presents low-rank bilinear ...             0
# 1    The paper implements low-rank bilinear pooling...             1
# 2    The paper presents various ablation studies of...             2
# 3                                 -Strengths:\n\n\n-1.             3
# 4    The paper presents new insights into element-w...             4
# ..                                                 ...           ...
# 112  -- Author only compares to methods that do not...            14
# 113  I would argue that a comparison with dynamic e...            15
# 114  --- Feedback LSTM uses prediction error as ext...            16
# 115  Also they don't propagate the prediction error...            17
# 116  ----In summary:\n---Pros: \n---- Interesting i...            18
#
# [117 rows x 6 columns]

# %% [markdown]
# ### 2. Compute RSA

# %%
from pathlib import Path

import pandas as pd
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, PegasusTokenizer
import argparse
from tqdm import tqdm

from pickle import dump
from rsasumm.rsa_reranker import RSAReranking

# %%
debug = False
def parse_summaries(path: Path) -> pd.DataFrame:
    
    try:
        summaries = pd.read_csv(path)
    except:
        raise ValueError(f"Unknown dataset {path}")

    # check if the dataframe has the right columns
    if not all(
        col in summaries.columns for col in ["index", "id", "text", "gold", "summary", "id_candidate"]
    ):
        raise ValueError(
            "The dataframe must have columns ['index', 'id', 'text', 'gold', 'summary', 'id_candidate']"
        )

    return summaries


def compute_rsa(summaries: pd.DataFrame, model, tokenizer, device):
    results = []
    for name, group in tqdm(summaries.groupby(["id"])):
        if debug:
            print("---candidates---")
            print(group.summary.unique().tolist())
            print("---end candidates---")
            #print number of candidates
            print(f"number of candidates:  {len(group.summary.unique().tolist())}")
            #TODO: based on reviews_app.py at line 113, compute uniqueness scores
            #candidates = group.summary.unique().tolist()
            #speaker_df = speaker_df.applymap(lambda x: math.exp(x))
            #for candidate in candidates:
            #    get sentences of the candidate text_sentences=...
            #    text_1_summaries = speaker_df.loc[candidate][text_sentences]
        if not debug:
            rsa_reranker = RSAReranking(
                model,
                tokenizer,
                device=device,
                candidates=group.summary.unique().tolist(), #TODO: check what is this.
                source_texts=group.text.unique().tolist(),
                #batch_size=32,
                rationality=3,
            )
            (
                best_rsa,
                best_base,
                speaker_df,
                listener_df,
                initial_listener,
                language_model_proba_df,
                initial_consensuality_scores,
                consensuality_scores,
                uniqueness_scores,
            ) = rsa_reranker.rerank(t=2) #maybe you should return here the uniqueness scores
        
            gold = group['gold'].tolist()[0]
            results.append(
                {
                    "id": name,
                    "best_rsa": best_rsa,  # best speaker score
                    "best_base": best_base,  # naive baseline
                    "speaker_df": speaker_df,  # all speaker results
                    "listener_df": listener_df,  # all listener results (chances of guessing correctly)
                    "initial_listener": initial_listener,
                    "language_model_proba_df": language_model_proba_df,
                    "initial_consensuality_scores": initial_consensuality_scores,
                    "consensuality_scores": consensuality_scores,  # uniqueness scores # TODO: did you write or it was already there? Answer: no, I did not write it. Ask professor how to extract it from the consensuality_scores
                    "uniqueness_scores": uniqueness_scores,  # uniqueness scores
                    "gold": gold,
                    "rationality": 3,  # hyperparameter
                    "text_candidates" : group
                }
            )
    if not debug:
        return results
    else:
        return None

import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
model_name = "google/pegasus-xsum"
summaries=output_path
# load the model and the tokenizer
print("Loading model...")
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
if "pegasus" in model_name: 
    print("Loading Pegasus Tokenizer")
    tokenizer = PegasusTokenizer.from_pretrained(model_name)
else:
    print("Loading Auto Tokenizer")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
print("Model loaded")
model = model.to(device)
print("Model to device")
# load the summaries
summaries = parse_summaries(summaries)
print("Summaries loaded")
# rerank the summaries
print("Computing RSA...")
results = compute_rsa(summaries, model, tokenizer, device)
results = {"results": results} # wrap the results in a dictionary

results["metadata/reranking_model"] = model_name
results["metadata/rsa_iterations"] = 3
# Out:
# Loading model...
# Some weights of PegasusForConditionalGeneration were not initialized from the model checkpoint at google/pegasus-xsum and are newly initialized: ['model.decoder.embed_positions.weight', 'model.encoder.embed_positions.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading Pegasus Tokenizer
# Model loaded
# Model to device
# Summaries loaded
# Computing RSA...
# 100%|██████████| 5/5 [01:54<00:00, 22.87s/it]
# 100%|██████████| 7/7 [03:22<00:00, 28.96s/it]]
# 100%|██████████| 2/2 [05:17<00:00, 158.53s/it]

# %%
summaries
# Out:
#     index                                         id  \
# 0       0  https://openreview.net/forum?id=r1rhWnZkg
# 1       0  https://openreview.net/forum?id=r1rhWnZkg
# 2       0  https://openreview.net/forum?id=r1rhWnZkg
# 3       0  https://openreview.net/forum?id=r1rhWnZkg
# 4       0  https://openreview.net/forum?id=r1rhWnZkg
# 5       0  https://openreview.net/forum?id=r1rhWnZkg
# 6       0  https://openreview.net/forum?id=r1rhWnZkg
# 7       0  https://openreview.net/forum?id=r1rhWnZkg
# 8       0  https://openreview.net/forum?id=r1rhWnZkg
# 9       0  https://openreview.net/forum?id=r1rhWnZkg
# 10      0  https://openreview.net/forum?id=r1rhWnZkg
# 11      0  https://openreview.net/forum?id=r1rhWnZkg
# 12      0  https://openreview.net/forum?id=r1rhWnZkg
# 13      0  https://openreview.net/forum?id=r1rhWnZkg
# 14      0  https://openreview.net/forum?id=r1rhWnZkg
# 15      0  https://openreview.net/forum?id=r1rhWnZkg
# 16      0  https://openreview.net/forum?id=r1rhWnZkg
# 17      0  https://openreview.net/forum?id=r1rhWnZkg
# 18      0  https://openreview.net/forum?id=r1rhWnZkg
# 19      0  https://openreview.net/forum?id=r1rhWnZkg
# 20      0  https://openreview.net/forum?id=r1rhWnZkg
# 21      0  https://openreview.net/forum?id=r1rhWnZkg
# 22      0  https://openreview.net/forum?id=r1rhWnZkg
# 23      0  https://openreview.net/forum?id=r1rhWnZkg
# 24      0  https://openreview.net/forum?id=r1rhWnZkg
# 25      0  https://openreview.net/forum?id=r1rhWnZkg
# 26      0  https://openreview.net/forum?id=r1rhWnZkg
# 27      0  https://openreview.net/forum?id=r1rhWnZkg
# 28      0  https://openreview.net/forum?id=r1rhWnZkg
# 29      1  https://openreview.net/forum?id=r1rhWnZkg
# 30      1  https://openreview.net/forum?id=r1rhWnZkg
# 31      1  https://openreview.net/forum?id=r1rhWnZkg
# 32      1  https://openreview.net/forum?id=r1rhWnZkg
# 33      1  https://openreview.net/forum?id=r1rhWnZkg
# 34      1  https://openreview.net/forum?id=r1rhWnZkg
# 35      1  https://openreview.net/forum?id=r1rhWnZkg
#
#                                                  text  \
# 0   Summary: The paper presents low-rank bilinear ...
# 1   Summary: The paper presents low-rank bilinear ...
# 2   Summary: The paper presents low-rank bilinear ...
# 3   Summary: The paper presents low-rank bilinear ...
# 4   Summary: The paper presents low-rank bilinear ...
# 5   Summary: The paper presents low-rank bilinear ...
# 6   Summary: The paper presents low-rank bilinear ...
# 7   Summary: The paper presents low-rank bilinear ...
# 8   Summary: The paper presents low-rank bilinear ...
# 9   Summary: The paper presents low-rank bilinear ...
# 10  Summary: The paper presents low-rank bilinear ...
# 11  Summary: The paper presents low-rank bilinear ...
# 12  Summary: The paper presents low-rank bilinear ...
# 13  Summary: The paper presents low-rank bilinear ...
# 14  Summary: The paper presents low-rank bilinear ...
# 15  Summary: The paper presents low-rank bilinear ...
# 16  Summary: The paper presents low-rank bilinear ...
# 17  Summary: The paper presents low-rank bilinear ...
# 18  Summary: The paper presents low-rank bilinear ...
# 19  Summary: The paper presents low-rank bilinear ...
# 20  Summary: The paper presents low-rank bilinear ...
# 21  Summary: The paper presents low-rank bilinear ...
# 22  Summary: The paper presents low-rank bilinear ...
# 23  Summary: The paper presents low-rank bilinear ...
# 24  Summary: The paper presents low-rank bilinear ...
# 25  Summary: The paper presents low-rank bilinear ...
# 26  Summary: The paper presents low-rank bilinear ...
# 27  Summary: The paper presents low-rank bilinear ...
# 28  Summary: The paper presents low-rank bilinear ...
# 29  Results on the VQA task are good for this simp...
# 30  Results on the VQA task are good for this simp...
# 31  Results on the VQA task are good for this simp...
# 32  Results on the VQA task are good for this simp...
# 33  Results on the VQA task are good for this simp...
# 34  Results on the VQA task are good for this simp...
# 35  Results on the VQA task are good for this simp...
#
#                                                  gold  \
# 0   The program committee appreciates the authors'...
# 1   The program committee appreciates the authors'...
# 2   The program committee appreciates the authors'...
# 3   The program committee appreciates the authors'...
# 4   The program committee appreciates the authors'...
# 5   The program committee appreciates the authors'...
# 6   The program committee appreciates the authors'...
# 7   The program committee appreciates the authors'...
# 8   The program committee appreciates the authors'...
# 9   The program committee appreciates the authors'...
# 10  The program committee appreciates the authors'...
# 11  The program committee appreciates the authors'...
# 12  The program committee appreciates the authors'...
# 13  The program committee appreciates the authors'...
# 14  The program committee appreciates the authors'...
# 15  The program committee appreciates the authors'...
# 16  The program committee appreciates the authors'...
# 17  The program committee appreciates the authors'...
# 18  The program committee appreciates the authors'...
# 19  The program committee appreciates the authors'...
# 20  The program committee appreciates the authors'...
# 21  The program committee appreciates the authors'...
# 22  The program committee appreciates the authors'...
# 23  The program committee appreciates the authors'...
# 24  The program committee appreciates the authors'...
# 25  The program committee appreciates the authors'...
# 26  The program committee appreciates the authors'...
# 27  The program committee appreciates the authors'...
# 28  The program committee appreciates the authors'...
# 29  The program committee appreciates the authors'...
# 30  The program committee appreciates the authors'...
# 31  The program committee appreciates the authors'...
# 32  The program committee appreciates the authors'...
# 33  The program committee appreciates the authors'...
# 34  The program committee appreciates the authors'...
# 35  The program committee appreciates the authors'...
#
#                                               summary  id_candidate
# 0   Summary: The paper presents low-rank bilinear ...             0
# 1   The paper implements low-rank bilinear pooling...             1
# 2   The paper presents various ablation studies of...             2
# 3                                -Strengths:\n\n\n-1.             3
# 4   The paper presents new insights into element-w...             4
# 5                                                 -2.             5
# 6   The paper presents a new model for the task of...             6
# 7   However, I have concerns about the statistical...             7
# 8                                                 -3.             8
# 9   The various design choices made in model devel...             9
# 10                  -Weaknesses/Suggestions:\n\n\n-1.            10
# 11  When authors explicitly (keeping rest of the m...            11
# 12  Hence, it could not be experimentally verified...            12
# 13                                                -2.            13
# 14  The authors argue that low-rank bilinear pooli...            14
# 15  So, could the authors please explain how does ...            15
# 16  Does the training time of the model reduce sig...            16
# 17             Can we train the model with less data?            17
# 18                                                -3.            18
# 19  One of the contributions of the paper is that ...            19
# 20  However, I am skeptical that the performance o...            20
# 21                                                -4.            21
# 22  I would like the authors to explicitly mention...            22
# 23       It is not very clear from reading the paper.            23
# 24                                                -5.            24
# 25  In the caption for Table 1, fix the following:...            25
# 26  However, it could not be justified that low-ra...            26
# 27  It does lead to reduction in number of paramet...            27
# 28  So, to be more convinced I would like the auth...            28
# 29  Results on the VQA task are good for this simp...             0
# 30  -Missing are some explanations about the langu...             1
# 31  Since the main contribution of the\n---paper s...             2
# 32  If you increase embedded and output dimensions...             3
# 33                       How is the question encoded?             4
# 34  Is word order preserved in this encoding, the ...             5
# 35  The meaning of visual attention in this model ...             6

# %%
df_results = pd.DataFrame(results["results"])
df_results.shape[0]
# Out:
# 2

# %%
##this is just to understand how to extract the uniqueness scores from the speaker_df in a single case. next cell implement this for each summary
import math
df_results = pd.DataFrame(results["results"])
index = 0
initial_text = df_results.iloc[index]["text_candidates"]["text"].unique()[0]
#get best rsa summary as concatenated text of array in best_rsa
df_results["best_rsa_summary"] = df_results["best_rsa"].apply(lambda x: " ".join(x))
df_results["best_base_summary"] = df_results["best_base"].apply(lambda x: " ".join(x))
speaker_df = df_results.iloc[index]["speaker_df"]
uniqueness_df = speaker_df.map(lambda x: math.exp(x))
print(type(uniqueness_df))
#text_1_summaries = uniqueness_df.loc[text1][text1_sentences] 
#text1_sentences = nltk.sent_tokenize(text1)
#get consensuality scores for the sentences in best rsa summary
uniqueness_scores= uniqueness_df.loc[initial_text][df_results["best_rsa"][index]].values
uniqueness_scores_norm = uniqueness_scores / uniqueness_scores.sum()
#associate text_summaries_norm to each sentence in the best rsa summary.
df_results["best_rsa_summary_uniqueness_scores"] = 0 #just to initialize
df_results["best_rsa_summary_uniqueness_scores"][0] = [uniqueness_scores_norm]
df_results["best_rsa_summary_uniqueness_scores"]
print(uniqueness_scores_norm)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# [9.99764439e-01 2.35561272e-04 2.09684636e-19]
# /var/folders/y2/yt_62_rn5r7g4sz81v1sf_bm0000gp/T/ipykernel_10419/3882898427.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_results["best_rsa_summary_uniqueness_scores"][0] = [uniqueness_scores_norm]
# /var/folders/y2/yt_62_rn5r7g4sz81v1sf_bm0000gp/T/ipykernel_10419/3882898427.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_results["best_rsa_summary_uniqueness_scores"][0] = [uniqueness_scores_norm]
# /var/folders/y2/yt_62_rn5r7g4sz81v1sf_bm0000gp/T/ipykernel_10419/3882898427.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[array([9.99764439e-01, 2.35561272e-04, 2.09684636e-19])]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_results["best_rsa_summary_uniqueness_scores"][0] = [uniqueness_scores_norm]

# %%
df_results = pd.DataFrame(results["results"])
#get best rsa summary as concatenated text of array in best_rsa
df_results["best_rsa_summary"] = df_results["best_rsa"].apply(lambda x: " ".join(x))
#get consensuality scores from speaker_df for the sentences in best rsa summary
df_results["initial_text"] =  df_results["text_candidates"].apply(lambda x: x["text"].unique()[0])
df_results["speaker_df"] = df_results["speaker_df"].apply(lambda x:   pd.DataFrame(x.map(lambda x: math.exp(x))))
df_results["uniqueness_scores"] = df_results.apply(lambda row: row["speaker_df"].loc[row["initial_text"]][row["best_rsa"]].values, axis=1)
df_results["uniqueness_scores_norm"] = df_results["uniqueness_scores"].apply(lambda x: x / x.sum())
df_results["uniqueness_scores_norm"][index]
df_results
# Out:
#                                              id  \
# 0  (https://openreview.net/forum?id=S1J0E-71l,)
# 1  (https://openreview.net/forum?id=r1rhWnZkg,)
#
#                                             best_rsa  \
# 0  [---Most of the equations presented in the pap...
# 1  [Summary: The paper presents low-rank bilinear...
#
#                                            best_base  \
# 0  [---Most of the equations presented in the pap...
# 1  [The paper presents various ablation studies o...
#
#                                           speaker_df  \
# 0                                                ...
# 1                                                ...
#
#                                          listener_df  \
# 0                                                ...
# 1                                                ...
#
#                                     initial_listener  \
# 0                                                ...
# 1                                                ...
#
#                              language_model_proba_df  \
# 0                                                ...
# 1                                                ...
#
#                         initial_consensuality_scores  \
# 0  Summary:\n---This paper proposes to use surpri...
# 1  Summary: The paper presents low-rank bilinear ...
#
#                                 consensuality_scores  \
# 0  Summary:\n---This paper proposes to use surpri...
# 1  Summary: The paper presents low-rank bilinear ...
#
#                                    uniqueness_scores  \
# 0  [0.13448573950974668, 3.1687096170732067e-05, ...
# 1  [0.03539040452453201, 2.5440130312699124e-52, ...
#
#                                                 gold  rationality  \
# 0  Based on the feedback, I'm going to be rejecti...            3
# 1  The program committee appreciates the authors'...            3
#
#                                      text_candidates  \
# 0       index                                    ...
# 1      index                                     ...
#
#                                     best_rsa_summary  \
# 0  ---Most of the equations presented in the pape...
# 1  Summary: The paper presents low-rank bilinear ...
#
#                                         initial_text  \
# 0  Summary:--------This paper proposes to use sur...
# 1  Summary: The paper presents low-rank bilinear ...
#
#                               uniqueness_scores_norm
# 0  [0.9997644387276039, 0.00023556127239604917, 2...
# 1  [0.9999999999993716, 7.18842597434807e-51, 6.2...

# %%
now = datetime.datetime.now()
date = now.strftime("%Y-%m-%d-%H-%M-%S")
output_dir = "../../output/"
output_path = f"{output_dir}-_-r3-_-rsa_reranked-{model_name.replace('/', '-')}.pk"
#output_path_txt = (
#    Path(args.output_dir) / f"{args.summaries.stem}-_-r3-_-rsa_reranked-{model_name.replace('/', '-')}.txt"
#)
output_path_txt = f"{output_dir}-_-r3-_-rsa_reranked-{date}-{model_name.replace('/', '-')}.txt"


#write also results to txt file
with open(output_path_txt, "wb") as f:
    f.write(str(results).encode('utf-8'))

# in case of scripted run, print the output path
print(output_path)

# %%
#convert json to dataframe
df_results = pd.DataFrame(results["results"])

# %%
df_results["consensuality_scores"][0].count() #34
df_results["consensuality_scores"][0] #consensuality_scores

# %%
df_results["gold"] #this is the reference summary.

# %%
pd.set_option('display.max_colwidth', None)
#df_results["text_candidates"][0] # it contains a dataframe with the gold summary (real summary) and the candidates for each review proposed.

# %%
df_results["text_candidates"][0]
#index is composed by the number of sentences in the review and the document id. 
#id_candidate is the id representing the candidate sentence 
#TODO: evaluate how best_base and best_rsa are computed. How sentences are chosen?.

# %%
#TODO
#replicate in pandas what happens in the code of review_app.py for what concerns the computation of the uniqueness scores.
#validate with manual computation on first summary (which basically means to compute the uniqueness scores of the first summary). --done, validated
